# %%
#open text file
text_file =open("Natural_Language_Processing_Text.txt")

#read
text = text_file.read()

print(type(text))
print(text)
print('\n')

#length of the text
print(len)
# Out:
# <class 'str'>
# Once upon a time there was an old mother pig who had three little pigs and not enough food to feed them. So when they were old enough, she sent them out into the world to seek their fortunes.
#
# The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. The second little pig worked a little bit harder but he was somewhat lazy too and he built his house out of sticks. Then, they sang and danced and played together the rest of the day.
#
# The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. It looked like it could withstand the strongest winds.
#
#
# <built-in function len>

# %%
#Word Cloud modification
##Install workclouud  
from wordcloud import WordCloud

# %%
#Library to plot wordcloud:
import matplotlib.pyplot as plt

# %%
#Generating:
wordcloud = WordCloud().generate(text)

# %%
#Plot the word cloud
plt.figure(figsize=(12,12))
plt.imshow(wordcloud)

#remove axis value:
plt.axis('off')
plt.show()

# %%
##Wordcloud but circle
import numpy as np
from PIL import Image
from wordcloud import WordCloud

# %%
char_mask = np.array(Image.open('circle.png'))
#generate word cloud
wordcloud = WordCloud(background_color="black", mask=char_mask).generate(text)

#Plot wordcloud
plt.figure(figsize=(8,8))
plt.imshow(wordcloud)

#to remove axis val:
plt.axis('off')
plt.show()

# %%
##Porter's Stemmer First Example
#Import stemming lib:
from nltk.stem import PorterStemmer

porter=PorterStemmer()

#Wordlist stemming;
wordlist =['Study', 'Studying', 'Studies','Studied' ]

for w in wordlist:
    print(porter.stem(w))
# Out:
# studi
# studi
# studi
# studi

# %%
##Porter's Stemmer Second Example
#Import stemming lib:
from nltk.stem import PorterStemmer

porter=PorterStemmer()

#Wordlist stemming;
wordlist =['Studies', 'Leaves', 'Decreases','Plays' ]

for w in wordlist:
    print(porter.stem(w))
# Out:
# studi
# leav
# decreas
# play

# %%
##Porter's Stemmer Second Example
#Import stemming lib:
from nltk.stem import SnowballStemmer

snowball =SnowballStemmer('english')

#Wordlist stemming;
wordlist =['Study', 'Studying', 'Studies','Studied' ]

for w in wordlist:
    print(porter.stem(w))
# Out:
# studi
# studi
# studi
# studi

# %%
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
#Stemmer and Lemmatizer
#Stemmer
from nltk.stem import PorterStemmer

stemmer= PorterStemmer()

print(stemmer.stem('studies'))
# Out:
# studi

# %%
#Lemmatizer
import nltk

# Download the WordNet data
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer

lemmatizer= WordNetLemmatizer()

print(lemmatizer.lemmatize('studies'))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# study
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#Demonstration

from nltk.stem import WordNetLemmatizer

lemmatizer= WordNetLemmatizer()

wordlist =['Study', 'Studying', 'Studies','Studied' ]

for w in wordlist:
    print(lemmatizer.lemmatize(w))
# Out:
# Study
# Studying
# Studies
# Studied

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer= WordNetLemmatizer()

wordlist =['Studies', 'Leaves', 'Decreases','Plays' ]

for w in wordlist:
    print(lemmatizer.lemmatize(w))
# Out:
# Studies
# Leaves
# Decreases
# Plays

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer= WordNetLemmatizer()

wordlist =['am', 'is', 'are','was', 'were' ]

for w in wordlist:
    print(lemmatizer.lemmatize(w, pos='v'))
# Out:
# be
# be
# be
# be
# be

# %%
#Lemmatizer with different POS values
from nltk.stem import WordNetLemmatizer

lemmatizer= WordNetLemmatizer()
print(lemmatizer.lemmatize('studying',pos='v'))

print(lemmatizer.lemmatize('studying',pos='n'))

print(lemmatizer.lemmatize('studying',pos='a'))

print(lemmatizer.lemmatize('studying',pos='r'))
# Out:
# study
# studying
# studying
# studying

# %%
import nltk

# Download the necessary data files for PoS tagging
nltk.download('averaged_perceptron_tagger')

# Perform PoS tagging
tag = nltk.pos_tag(["Studying", "Study"])
print(tag)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [('Studying', 'VBG'), ('Study', 'NN')]
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
from nltk.tokenize import word_tokenize

sentence = "A very beautiful young lady is walking on the beach"
tokenized_words = word_tokenize(sentence)

tagged_words = nltk.pos_tag(tokenized_words)
print(tagged_words)
# Out:
# [('A', 'DT'), ('very', 'RB'), ('beautiful', 'JJ'), ('young', 'JJ'), ('lady', 'NN'), ('is', 'VBZ'), ('walking', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('beach', 'NN')]

# %%
##Chunking
# ?  optional character
# * 0 or more repetittions
grammar = 'NP : {<DT>?<JJ>*<NN>}'
parser = nltk.RegexpParser(grammar)
#Creating a parser:
output = parser.parse(tagged_words)
print(output)

#to vizualize
output.draw()
# Out:
# (S
#   A/DT
#   very/RB
#   (NP beautiful/JJ young/JJ lady/NN)
#   is/VBZ
#   walking/VBG
#   on/IN
#   (NP the/DT beach/NN))

# %%
##Chunking
# * -0 or more repetitions
# + - 1 or ore repititons
#taking whole string and then excluding adjectives from that chunk

grammar = r"""NP: {</*>+}
                }<JJ>+{"""

parser = nltk.RegexpParser(grammar)
#Creating a parser:
output = parser.parse(tagged_words)
print(output)

#to vizualize
output.draw()
# Out:
# (S
#   A/DT
#   very/RB
#   beautiful/JJ
#   young/JJ
#   lady/NN
#   is/VBZ
#   walking/VBG
#   on/IN
#   the/DT
#   beach/NN)
